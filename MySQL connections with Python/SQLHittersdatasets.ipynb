# %% [markdown]
# ### SQL Hitters dataset

# %%
# !pip install sqlalchemy==1.3.9 ipython-sql

# %% [markdown]
# ### Restart and run all cell

# %%
# %load_ext sql

# %%
import csv, sqlite3
con = sqlite3.connect("hitters.db")
cur = con.cursor()

# %%
# %sql sqlite:///hitters.db

# %%
# Reading datset in pandas
import pandas as pd
df = pd.read_csv("D:/DATA SCIENCE/ADVANCE PYTHON/Class 6 DT 05.10.2023/hitters.csv")

# %%
df.head()
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     Andy Allanson    293    66      1    30   29     14      1     293
# 1        Alan Ashby    315    81      7    24   38     39     14    3449
# 2       Alvin Davis    479   130     18    66   72     76      3    1624
# 3      Andre Dawson    496   141     20    65   78     37     11    5628
# 4  Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
#
#    Salary  NewLeague
# 0     NaN          A
# ...

# %%
# Saving to SQL
df.to_sql("hits", con, if_exists='replace', index=False)
# Out:
# 322

# %%
# %%sql
# SELECT * FROM hits
# LIMIT 5;
# Out:
#  * sqlite:///hitters.db
# Done.
# [('Andy Allanson', 293, 66, 1, 30, 29, 14, 1, 293, 66, 1, 30, 29, 14, 'A', 'E', 446, 33, 20, None, 'A'),
#  ('Alan Ashby', 315, 81, 7, 24, 38, 39, 14, 3449, 835, 69, 321, 414, 375, 'N', 'W', 632, 43, 10, 475.0, 'N'),
#  ('Alvin Davis', 479, 130, 18, 66, 72, 76, 3, 1624, 457, 63, 224, 266, 263, 'A', 'W', 880, 82, 14, 480.0, 'A'),
#  ('Andre Dawson', 496, 141, 20, 65, 78, 37, 11, 5628, 1575, 225, 828, 838, 354, 'N', 'E', 200, 11, 3, 500.0, 'N'),
#  ('Andres Galarraga', 321, 87, 10, 39, 42, 30, 2, 396, 101, 12, 48, 46, 33, 'N', 'E', 805, 40, 4, 91.5, 'N')]

# %% [markdown]
# ### Find out no missing values in each columns

# %%
# %%sql
# SELECT * FROM hits
# WHERE Salary IS NULL
# Out:
#  * sqlite:///hitters.db
# Done.
# [('Andy Allanson', 293, 66, 1, 30, 29, 14, 1, 293, 66, 1, 30, 29, 14, 'A', 'E', 446, 33, 20, None, 'A'),
#  ('Billy Beane', 183, 39, 3, 20, 15, 11, 3, 201, 42, 3, 20, 16, 11, 'A', 'W', 118, 0, 0, None, 'A'),
#  ('Bruce Bochte', 407, 104, 6, 57, 43, 65, 12, 5233, 1478, 100, 643, 658, 653, 'A', 'W', 912, 88, 9, None, 'A'),
#  ('Bob Boone', 22, 10, 1, 4, 2, 1, 6, 84, 26, 2, 9, 9, 3, 'A', 'W', 812, 84, 11, None, 'A'),
#  ('Bobby Grich', 313, 84, 9, 42, 30, 39, 17, 6890, 1833, 224, 1033, 864, 1087, 'A', 'W', 127, 221, 7, None, 'A'),
#  ('Bob Horner', 517, 141, 27, 70, 87, 52, 9, 3571, 994, 215, 545, 652, 337, 'N', 'W', 1378, 102, 8, None, 'N'),
#  ('Bobby Meacham', 161, 36, 0, 19, 10, 17, 4, 1053, 244, 3, 156, 86, 107, 'A', 'E', 70, 149, 12, None, 'A'),
#  ('Ben Oglivie', 346, 98, 5, 31, 53, 30, 16, 5913, 1615, 235, 784, 901, 560, 'A', 'E', 0, 0, 0, None, 'A'),
# ...

# %% [markdown]
# ### Find out people who have batted more than 400 matches

# %%
# %%sql
# SELECT count(*) FROM hits
# WHERE atBat>400;
# Out:
#  * sqlite:///hitters.db
# Done.
# [(151,)]

# %%
len(df[df['AtBat']>400])
# Out:
# 151

# %% [markdown]
# ### Find out name of player who has hit max home runs

# %%
# %%sql
# SELECT MAX(HmRun) FROM hits;
# Out:
#  * sqlite:///hitters.db
# Done.
# [(40,)]

# %%
# %%sql
# SELECT Name From hits
# WHERE HmRun = (SELECT MAX(HmRun) From Hits);
# Out:
#  * sqlite:///hitters.db
# Done.
# [('Jesse Barfield',)]

# %%
x = df.max()['HmRun']
x
# Out:
# 40

# %%
df[df['HmRun']==x]['Name']
# Out:
# 136    Jesse Barfield
# Name: Name, dtype: object

# %% [markdown]
# ### Find out league wise total number of players

# %%
# %%sql
# SELECT League, count(League) as PlayerNum FROM hits
# GROUP BY League
# Out:
#  * sqlite:///hitters.db
# Done.
# [('A', 175), ('N', 147)]

# %%
df.groupby(by='League').count()['Name']
# Out:
# League
# A    175
# N    147
# Name: Name, dtype: int64

# %%
# %%sql
# SELECT Division, SUM(Salary) as totalSalary FROM hits
# GROUP BY Division;
# Out:
#  * sqlite:///hitters.db
# Done.
# [('E', 80531.006), ('W', 60417.501000000004)]

# %%
df.groupby(by='Division').sum()['Salary']
# Out:
# Division
# E    80531.006
# W    60417.501
# Name: Salary, dtype: float64

# %% [markdown]
# ### Find out five most senior players

# %%
# %%sql
# SELECT Name, Years FROM hits
# ORDER BY Years DESC
# LIMIT 5;
# Out:
#  * sqlite:///hitters.db
# Done.
# [('Pete Rose', 24),
#  ('Tony Perez', 23),
#  ('Graig Nettles', 20),
#  ('Reggie Jackson', 20),
#  ('Ted Simmons', 19)]
